# %% [markdown]
# # **Salary prediction **

# %% [markdown]
# ##EDA

# %%
cat_deg,num_deg,car_deg=degisken_tiplerine_ayirma(df, 10, 20)

plt.figure(1)
plt.figure(figsize=(30,15))
sns.barplot(x=df.groupby("Job Title").mean()["Avg Salary(K)"].sort_values(ascending=False).head(15).index,y=df.groupby("Job Title").mean()["Avg Salary(K)"].sort_values(ascending=False).head(15))
plt.xticks(rotation=90)
plt.show()
# Out:
# Dataset kolon/değişken sayısı: 41
# Dataset satır/veri sayısı: 742
# ********************************************
# Datasetin numeric değişken sayısı: 6
# Datasetin numeric değişkenler: ['Rating', 'Founded', 'Lower Salary', 'Upper Salary', 'Avg Salary(K)', 'Age']
# ********************************************
# Datasetin categoric değişken sayısı: 24
# Datasetin categoric değişkenler: ['Size', 'Type of ownership', 'Revenue', 'job_title_sim', 'seniority_by_title', 'Degree', 'Hourly', 'Employer provided', 'Python', 'spark', 'aws', 'excel', 'sql', 'sas', 'keras', 'pytorch', 'scikit', 'tensor', 'hadoop', 'tableau', 'bi', 'flink', 'mongo', 'google_an']
# ********************************************
# Datasetin cardinal değişken sayısı: 11
# Datasetin cardinal değişkenler: ['Job Title', 'Salary Estimate', 'Job Description', 'Company Name', 'Location', 'Headquarters', 'Industry', 'Sector', 'Competitors', 'company_txt', 'Job Location']
# ********************************************

# %%
plt.figure(2)
plt.figure(figsize=(30,15))
sns.barplot(x=df.groupby("Location").mean()["Avg Salary(K)"].sort_values(ascending=False).head(15).index,y=df.groupby("Location").mean()["Avg Salary(K)"].sort_values(ascending=False).head(15))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(3)
plt.figure(figsize=(30,15))
sns.barplot(x=df.groupby("Industry").mean()["Avg Salary(K)"].sort_values(ascending=False).head(15).index,y=df.groupby("Industry").mean()["Avg Salary(K)"].sort_values(ascending=False).head(15))
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##K-MEANS METHOD

# %%
kmeans = KMeans(n_clusters=4)
k_fit = kmeans.fit(df[num_deg])
kumeler = kmeans.labels_
df["Class"]=kumeler
df = pd.DataFrame(df)
df.head()
# Out:
#                        Job Title              Salary Estimate                                    Job Description  Rating                                Company Name         Location    Headquarters          Size  Founded   Type of ownership                          Industry                        Sector                           Revenue                                        Competitors  Hourly  Employer provided  Lower Salary  Upper Salary  Avg Salary(K)  \
# index
# 0                 Data Scientist   $53K-$91K (Glassdoor est.)  Data Scientist\nLocation: Albuquerque, NM\nEdu...   3.800                      Tecolote Research\n3.8  Albuquerque, NM      Goleta, CA   501 - 1000      1973   Company - Private               Aerospace & Defense           Aerospace & Defense         $50 to $100 million (USD)                                                 -1       0                  0            53            91         72.000
# ...

# %%
plt.figure(4)
plt.figure(figsize=(12,9))
sns.barplot(x=df.groupby("Class").mean()["Avg Salary(K)"].sort_values(ascending=False).index,y=df.groupby("Class").mean()["Avg Salary(K)"].sort_values(ascending=False))
plt.show()

# %% [markdown]
# ##FORECASTING AVG SALARY BASED ON PROGRAMMING KNOWLEDGE

# %%
new_user_3_knowledge=["Python","bi","tableau"] #I chosen 3 programming knowledge for user.
print(r"Users Estimated Salary is :",calculate_estimated_salary(df, new_user_3_knowledge))
# Out:
# Users Estimated Salary is : 105.72368421052632
